# %% [markdown]
# # 🌸 Iris Dataset Exploratory Data Analysis (EDA)
#
# ## Objective
# The objective of this ansysis is to explore the Iris dataset, understand its structure, and identify patterns and relationships between features using data visualization techniques.
#
# ## Dataset Description
# The Iris dataset contains measurements of iris flowers from three different species:
# - Setosa
# - Versicolor
# - Virginica
# ### Features:
# - Sepal Length
# - Sepal Width
# - Petal Length
# - Petal Width
# - Species
#
# This dataset is widely used for classification and data analysis tasks.

# %%
# Imported necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set visual style
sns.set(style="whitegrid")

# %%
# Load Iris dataset from seaborn
df = sns.load_dataset('iris')

# Displaying the first 5 rows
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape # Shape of dataset
# Out:
# (150, 5)

# %%
df.columns # Column names
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='str')

# %%
df.info() # Data info like data types and non-null counts
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB

# %%
df.describe()  # Statistical summary
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ___

# %% [markdown]
# ## **Observations till Now**
#
# - The dataset contains 150 rows and 5 columns.
# - There are no missing values in the dataset.
# - All feature columns are numerical except the species column.
# - The dataset appears clean and ready for analysis.

# %% [markdown]
# ___

# %% [markdown]
# # VISUALIZATION & INSIGHTS

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(x='sepal_length', y='petal_length', hue='species', data=df)
plt.title('Sepal Length vs Petal Length')
plt.show()

# %% [markdown]
# ## 📈 Insight from the Scatter Plot
#
# - Setosa species is clearly separable from the other two.
# - Versicolor and Virginica show some overlap.
# - Petal length is a strong distinguishing feature.

# %% [markdown]
# ## Histogram

# %%
# Histogram for Sepal Length
plt.figure()
df['sepal_length'].hist()
plt.title('Distribution of Sepal Length')
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 📊 Insight from the Histogram.
#
# - The distribution appears approximately normal.
# - Most values fall within a mid-range, with no extreme skewness.

# %% [markdown]
# ## Box Plot

# %%
# Box plot for Sepal Width across species
plt.figure()
sns.boxplot(x='species', y='sepal_width', data=df)
plt.title('Sepal Width by Species')
plt.show()

# %% [markdown]
# ## 📦 Insight from box plot
#
# - Some minor outliers are visible.
# - Setosa tends to have higher sepal width compared to others.
# - Variation differs across species.

# %% [markdown]
# ## Pairplot

# %%
# Pairplot for all features
sns.pairplot(df, hue='species')
plt.show()

# %% [markdown]
# ## Insight from Pair Plot
#
# - Petal length and petal width provide strong separation between species.
# - Setosa is linearly separable from others.
# - Versicolor and Virginica are closer in feature space.

# %% [markdown]
# # ✅ Conclusion
#
# - The dataset is clean with no missing values.
# - Petal features (length & width) are the most important for distinguishing species.
# - Setosa species is easily separable, while Versicolor and Virginica show overlap.
# - Visualizations help in understanding feature relationships effectively.
#
# ## Final Note
# This analysis demonstrates the importance of exploratory data analysis (EDA) before applying machine learning models.

# %% [markdown]
# <div align="center" style="font-size:28px; font-weight:bold; color:#FFFFFF;">
#
# ## ✨ Thank You ✨
#
# </div>
